# %% [markdown]
# # HDA AI Assistant - Colab Runner
#
# Use this notebook to run the FastAPI backend with GPU acceleration.
#
# ### Instructions:
# 1.  **Upload Files**: Upload your project files (app.py, requirements.txt, ml/, static/, templates/) to the Colab runtime (e.g., drag and drop the folder or zip/unzip it).
# 2.  **Runtime**: Ensure you are using a GPU Runtime (Runtime > Change runtime type > T4 GPU).
# 3.  **Ngrok Token**: You need a free Authtoken from [dashboard.ngrok.com](https://dashboard.ngrok.com).

# %%
# 1. Verify GPU
# !nvidia-smi

# %%
# 2. Install Dependencies
# !pip install -r ../requirements.txt
# !pip install pyngrok nest_asyncio
# Out:
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: '../requirements.txt'

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-5c4a47a8-ece0-4cbd-a5cb-318b52947da6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5c4a47a8-ece0-4cbd-a5cb-318b52947da6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# 3. Setup Ngrok Tunnel & Run Server
import os
import threading
from pyngrok import ngrok, conf

# ENTER YOUR NGROK TOKEN HERE
NGROK_TOKEN = "YOUR_NGROK_TOKEN_HERE"

conf.get_default().auth_token = NGROK_TOKEN

# Open a HTTP tunnel on the default port 8000
public_url = ngrok.connect(8000).public_url
print(f"\n🚀 Public URL: {public_url}\n")

# Run FastAPI with Uvicorn in background
import uvicorn
from app import app
import nest_asyncio

nest_asyncio.apply()

uvicorn.run(app, host="0.0.0.0", port=8000)
